# %%
# CELDAS YA EJECUTADAS EN EL NOTEBOOK ORIGINAL
# (instalaciones, carga de datos, creación de la tabla SPACEXTABLE, etc.)
# --------------------------------------------------------------
# !pip install sqlalchemy==1.3.9
# !pip install ipython-sql
# %load_ext sql
import csv, sqlite3
import pandas as pd

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %sql sqlite:///my_data1.db

df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False, method="multi")

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# %sql CREATE TABLE SPACEXTABLE AS SELECT * FROM SPACEXTBL WHERE Date IS NOT NULL;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       1 # CELDAS YA EJECUTADAS EN EL NOTEBOOK ORIGINAL
#       2 # (instalaciones, carga de datos, creación de la tabla SPACEXTABLE, etc.)
#       3 # --------------------------------------------------------------
#       4 # !pip install sqlalchemy==1.3.9
#       5 # !pip install ipython-sql
# ----> 6 get_ipython().run_line_magic('load_ext', 'sql')
#       7 import csv, sqlite3
#       8 import pandas as pd
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
# ...

# %%
#Tarea1
# %%sql
SELECT DISTINCT "Launch_Site"
FROM SPACEXTABLE;
# Out:
#   Cell In[4], line 3
#     SELECT DISTINCT "Launch_Site"
#            ^
# SyntaxError: invalid syntax

# %%
#Tarea2
# %%sql
SELECT *
FROM SPACEXTABLE
WHERE "Launch_Site" LIKE 'CCA%'
LIMIT 5;

# %%
#tarea3
# %%sql
SELECT SUM("Payload_Mass_kg") AS Total_Payload_Mass_NASA_CRS
FROM SPACEXTABLE
WHERE "Customer" LIKE '%NASA (CRS)%';

# %%
#tarea4
# %%sql
SELECT AVG("Payload_Mass_kg") AS Avg_Payload_F9_v1_1
FROM SPACEXTABLE
WHERE "Booster_Version" = 'F9 v1.1';

# %%
#tarea5
# %%sql
SELECT MIN(Date) AS First_Successful_Ground_Pad_Landing
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (ground pad)';

# %%
#tarea6
# %%sql
SELECT "Booster_Version"
FROM SPACEXTABLE
WHERE "Landing_Outcome" = 'Success (drone ship)'
  AND "Payload_Mass_kg" > 4000
  AND "Payload_Mass_kg" < 6000;

# %%
#tarea7
# %%sql
SELECT 
    SUM(CASE WHEN "Mission_Outcome" LIKE '%Success%' THEN 1 ELSE 0 END) AS Successful_Missions,
    SUM(CASE WHEN "Mission_Outcome" LIKE '%Failure%' THEN 1 ELSE 0 END) AS Failed_Missions
FROM SPACEXTABLE;

# %%
#tarea8
# %%sql
SELECT "Booster_Version"
FROM SPACEXTABLE
WHERE "Payload_Mass_kg" = (
    SELECT MAX("Payload_Mass_kg")
    FROM SPACEXTABLE
);

# %%
#tarea9
# %%sql
SELECT 
    substr(Date, 6, 2) AS Month,
    "Landing_Outcome",
    "Booster_Version",
    "Launch_Site"
FROM SPACEXTABLE
WHERE substr(Date, 0, 5) = '2015'
  AND "Landing_Outcome" = 'Failure (drone ship)';

# %% [markdown]
# #tarea10
# %%sql
# SELECT
#     "Landing_Outcome",
#     COUNT(*) AS Count
# FROM SPACEXTABLE
# WHERE Date BETWEEN '2010-06-04' AND '2017-03-20'
# GROUP BY "Landing_Outcome"
# ORDER BY Count DESC;

# %%
#tare10
# %%sql
SELECT 
    "Landing_Outcome",
    COUNT(*) AS Count
FROM SPACEXTABLE
WHERE Date BETWEEN '2010-06-04' AND '2017-03-20'
GROUP BY "Landing_Outcome"
ORDER BY Count DESC;
